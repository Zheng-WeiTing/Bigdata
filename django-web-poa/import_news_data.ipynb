# %%
import os
import sys
import pandas as pd
import argparse
from datetime import datetime
import pathlib

# 新增：將上一層目錄加入 sys.path
parent_path = pathlib.Path().absolute().parent
sys.path.insert(0, str(parent_path))
# Setup Django environment
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'website_configs.settings')
import django
django.setup()
# 重要：設定環境變數以允許在 Jupyter 的異步環境中執行同步操作
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Now we can import Django models
from app_user_keyword_db.models import NewsData

# %%
# Read CSV file
csv_file_path = '//Users/xx/Library/CloudStorage/GoogleDrive-qwas65412@gmail.com/我的雲端硬碟/7.碩士班/Bigdata/Day-12/app_user_keyword_sentiment/dataset/ltn_news_preprocessed.csv'
# csv_file_path = '../app_user_keyword/dataset/cna_news_preprocessed_12weeks.csv'
df = pd.read_csv(csv_file_path, sep='|')

# Process each row and create a NewsData object
for idx, row in df.iterrows():
    try:
        # Convert date string to datetime object
        date_obj = datetime.strptime(row['date'], '%Y-%m-%d').date()

        # Create or update NewsData object
        news_data, created = NewsData.objects.update_or_create(
            item_id=row['item_id'],
            defaults={
                'date': date_obj,
                'category': row['category'],
                'title': row['title'],
                'content': row['content'],
                'sentiment': row['sentiment'],
                'summary': row['summary'],
                'top_key_freq': row['top_key_freq'],
                'tokens': row['tokens'],
                'tokens_v2': row['tokens_v2'],
                'entities': row['entities'],
                'token_pos': row['token_pos'],
                'link': row['link'],
                'photo_link': row['photo_link'] if row['photo_link'] != "" and not pd.isna(row['photo_link']) else None,
            }
        )
        if created:
            print(f"Created new NewsData object with item_id: {row['item_id']}")
        else:
            print(f"Updated existing NewsData object with item_id: {row['item_id']}")
    except Exception as e:
        print(f"Error at row {idx}: {e}")
        print(row)
# photo_link 欄位的值可能為以下幾種情況：
# 實際有值的 URL 字串
# 空字串 ("")
# Pandas NaN 值（當 CSV 檔案中該欄位為空時）
# None 值
# Out:
# Error at row 0: no such table: news_data2
# item_id                                       politics_20250327_1
# date                                                   2025-03-27
# category                                                       政治
# title                             石碇、坪林行動治理 侯友宜：加強偏鄉加壓抽水站及自來水工程進度
# content         新北市長侯友宜27日率領市府團隊前往石碇區及坪林區座談，侯友宜表示，有關偏鄉地區加壓抽水站、...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('市府', 3), ('地區', 3), ('侯友宜', 2), ('坪林區', 2),...
# tokens          ['新北', '市長', '侯友宜', '27日', '率領', '市府', '團隊', '...
# tokens_v2       ['新北', '市長', '侯友宜', '市府', '團隊', '石碇區', '坪林區', ...
# entities        [NerToken(word='新北', ner='GPE', idx=(0, 2)), N...
# token_pos       [('新北', 'Nc'), ('市長', 'Na'), ('侯友宜', 'Nb'), ('...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 0, dtype: object
# Error at row 1: no such table: news_data2
# item_id                                       politics_20250327_2
# date                                                   2025-03-27
# category                                                       政治
# title                                     75學者挺亞亞！ 王定宇曝背景：是能代表什麼？
# content         中配劉振亞公開主張武統台灣被限期出境，昨天已經回到中國，中研院院士陳培哲等75名學者昨發聯合...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('中國', 7), ('學者', 6), ('台灣', 5), ('武統', 4), (...
# tokens          ['中配', '劉振亞', '公開', '主張', '武統', '台灣', '被', '限期...
# tokens_v2       ['中配', '劉振亞', '武統', '台灣', '中國', '中研院', '院士', '...
# entities        [NerToken(word='劉振亞', ner='PERSON', idx=(2, 5)...
# token_pos       [('中配', 'Nb'), ('劉振亞', 'Nb'), ('公開', 'VHC'), (...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 1, dtype: object
# Error at row 2: no such table: news_data2
# item_id                                       politics_20250327_3
# date                                                   2025-03-27
# category                                                       政治
# title                             高雄無盟爭取東高雄設棒球場  陳其邁允諾卸任前整建美濃國中球場
# content         高市議會無黨團結聯盟今聯合質詢時鎖定機場、原民、東高雄大眾運輸等議題，並提到東高雄棒球風氣旺...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('高雄', 8), ('議題', 3), ('棒球場', 3), ('完成', 3), ...
# tokens          ['高市', '議會', '無', '黨', '團結', '聯盟', '今', '聯合', ...
# tokens_v2       ['高市', '議會', '聯盟', '鎖定', '機場', '原民', '高雄', '運輸...
# entities        [NerToken(word='陳其邁', ner='PERSON', idx=(66, 6...
# token_pos       [('高市', 'Nc'), ('議會', 'Nc'), ('無', 'VJ'), ('黨'...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 2, dtype: object
# Error at row 3: no such table: news_data2
# item_id                                       politics_20250327_4
# date                                                   2025-03-27
# category                                                       政治
# title                             馬治薇收中國錢參選判刑 律師稱未修法不能視為「境外敵對勢力」
# content         民眾黨前桃園市黨部發言人馬治薇去年以無黨籍身分競選桃園市第一選區立委，被檢調指控接受中國對台...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('馬治薇', 12), ('中國', 6), ('勢力', 6), ('起訴', 5),...
# tokens          ['民眾黨', '前', '桃園市', '黨部', '發言人', '馬治薇', '去年', ...
# tokens_v2       ['民眾黨', '桃園市', '黨部', '發言人', '馬治薇', '黨籍', '身分',...
# entities        [NerToken(word='民眾黨', ner='ORG', idx=(0, 3)), ...
# token_pos       [('民眾黨', 'Nb'), ('前', 'Nes'), ('桃園市', 'Nc'), (...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 3, dtype: object
# Error at row 4: no such table: news_data2
# item_id                                       politics_20250327_5
# date                                                   2025-03-27
# category                                                       政治
# title                                鼓吹武統戰爭應立專法管制？ 吳思瑤：禁止暴力言論舉世皆然
# content         中配網紅「亞亞在台灣」劉振亞因涉武統言論遭移民署廢止居留許可，外界關注如何管制鼓吹戰爭或武統...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('言論', 11), ('台灣', 7), ('自由', 6), ('戰爭', 5), ...
# tokens          ['中配網', '紅', '「', '亞亞', '在', '台灣', '」', '劉振亞',...
# tokens_v2       ['亞亞', '台灣', '劉振亞', '言論', '移民署', '廢止', '管制', '...
# entities        [NerToken(word='劉振亞', ner='PERSON', idx=(11, 1...
# token_pos       [('中配網', 'Ng'), ('紅', 'VH'), ('「', 'PARENTHESI...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 4, dtype: object
# Error at row 5: no such table: news_data2
# item_id                                       politics_20250327_6
# date                                                   2025-03-27
# category                                                       政治
# title                                檢調偵辦罷免案死亡連署 凌濤批：這是什麼樣的準戒嚴狀態？
# content         針對檢調單位全力偵辦立委罷免案死亡連署，國民黨智庫副執行長凌濤今日質疑，無論是死亡連署或偽造...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('國民黨', 4), ('偽造', 4), ('文書', 4), ('司法', 3), ...
# tokens          ['針對', '檢調', '單位', '全力', '偵辦', '立委', '罷免案', '死...
# tokens_v2       ['檢調', '單位', '偵辦', '立委', '罷免案', '連署', '國民黨', '...
# entities        [NerToken(word='國民黨', ner='ORG', idx=(20, 23))...
# token_pos       [('針對', 'P'), ('檢調', 'Na'), ('單位', 'Na'), ('全力...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 5, dtype: object
# Error at row 6: no such table: news_data2
# item_id                                       politics_20250327_7
# date                                                   2025-03-27
# category                                                       政治
# title                                   光田向上院區開幕賴清德、盧秀燕同框 兩人互動受關注
# content         台中海線光田綜合醫院向上院區於去年底落成開始運作，今日由總統賴清德主持開幕典禮，台中市長盧秀...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('賴清德', 10), ('盧秀燕', 9), ('醫院', 5), ('台中', 3)...
# tokens          ['台中', '海線', '光田', '綜合', '醫院', '向', '上', '院區',...
# tokens_v2       ['台中', '海線', '光田', '醫院', '院區', '總統', '賴清德', '主...
# entities        [NerToken(word='去年底', ner='DATE', idx=(15, 18)...
# token_pos       [('台中', 'Nc'), ('海線', 'Na'), ('光田', 'Nb'), ('綜...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 6, dtype: object
# Error at row 7: no such table: news_data2
# item_id                                       politics_20250327_8
# date                                                   2025-03-27
# category                                                       政治
# title                                   立委批等不到新版委員提名名單 NCC：屬行政院職權
# content         去年「國家通訊傳播委員會（NCC）組織法」修法通過迄今，NCC委員人數仍不足半數，導致多項業...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('委員', 15), ('委員會', 8), ('立委', 7), ('行政院', 6)...
# tokens          ['去年', '「', '國家', '通訊', '傳播', '委員會', '（', 'NCC...
# tokens_v2       ['國家', '通訊', '委員會', '組織法', '通過', '委員', '人數', '...
# entities        [NerToken(word='國家通訊傳播委員會', ner='LAW', idx=(3,...
# token_pos       [('去年', 'Nd'), ('「', 'PARENTHESISCATEGORY'), (...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 7, dtype: object
# Error at row 8: no such table: news_data2
# item_id                                       politics_20250327_9
# date                                                   2025-03-27
# category                                                       政治
# title                            「全社會防衛韌性實地演練」登場！蕭美琴偕各國使節觀摩應變中心開設
# content         總統府首場「全社會防衛韌性委員會實地演練」今（27）日在台南登場，副總統蕭美琴率全社會防衛韌...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('社會', 12), ('韌性', 9), ('演練', 9), ('防衛', 6), ...
# tokens          ['總統府', '首', '場', '「', '全', '社會', '防衛', '韌性', ...
# tokens_v2       ['總統府', '社會', '防衛', '韌性', '委員會', '演練', '台南', '...
# entities        [NerToken(word='首場「全社會防衛韌性委員會實地演練', ner='EVENT...
# token_pos       [('總統府', 'Nc'), ('首', 'Nes'), ('場', 'Nf'), ('「...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 8, dtype: object
# Error at row 9: no such table: news_data2
# item_id                                      politics_20250327_10
# date                                                   2025-03-27
# category                                                       政治
# title                              港澳人士來台擬增「長期居留」 陸委會：已在台居留港人會有配套
# content         因應中共統戰滲透，賴清德總統日前宣布，港澳人士來台定居、居留等相關制度，將增列「長期居留」規...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('港澳', 10), ('政府', 7), ('策進會', 6), ('台灣', 5),...
# tokens          ['因應', '中共', '統戰', '滲透', '，', '賴清德', '總統', '日前...
# tokens_v2       ['中共', '統戰', '賴清德', '總統', '宣布', '港澳', '人士', '制...
# entities        [NerToken(word='中共', ner='ORG', idx=(2, 4)), N...
# token_pos       [('因應', 'VJ'), ('中共', 'Nb'), ('統戰', 'Na'), ('滲...
# link            https://news.ltn.com.tw/news/politics/breaking...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 9, dtype: object
# Error at row 10: no such table: news_data2
# item_id                                        society_20250327_1
# date                                                   2025-03-27
# category                                                       社會
# title                               男在母租屋洗澡一氧化碳中毒亡  高院判房東無罪因無通風不良
# content         張姓房東將房屋租給陳姓婦人，不料，陳婦的兒子在浴室洗澡時，疑因瓦斯燃燒不完全，吸入過多一氧化...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('房東', 6), ('房屋', 6), ('安裝', 6), ('熱水器', 5), ...
# tokens          ['張姓', '房東', '將', '房屋', '租給', '陳姓', '婦人', '，',...
# tokens_v2       ['張姓', '房東', '房屋', '陳姓', '婦人', '陳婦', '兒子', '浴室...
# entities        [NerToken(word='張', ner='PERSON', idx=(0, 1)),...
# token_pos       [('張姓', 'Nb'), ('房東', 'Na'), ('將', 'P'), ('房屋'...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 10, dtype: object
# Error at row 11: no such table: news_data2
# item_id                                        society_20250327_2
# date                                                   2025-03-27
# category                                                       社會
# title                                     男友闖包廂「抓姦」 女友「抱緊」害他差點被砍死
# content         羅姓女子與施姓男子半夜相約到KTV歡唱，羅女的男友李男得知此事，跑到包廂內質問兩人，羅女擔心...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('李男', 14), ('施男', 7), ('羅女', 4), ('包廂', 3), ...
# tokens          ['羅姓', '女子', '與', '施姓', '男子', '半夜', '相約', '到',...
# tokens_v2       ['羅姓', '女子', '施姓', '男子', '歡唱', '羅女', '男友', '李男...
# entities        [NerToken(word='羅', ner='PERSON', idx=(0, 1)),...
# token_pos       [('羅姓', 'Nb'), ('女子', 'Na'), ('與', 'Caa'), ('施...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 11, dtype: object
# Error at row 12: no such table: news_data2
# item_id                                        society_20250327_3
# date                                                   2025-03-27
# category                                                       社會
# title                                          疲勞駕駛打瞌睡 他失控自撞分隔島翻覆
# content         陳姓男子今天凌晨3時許駕駛自小客車，行經新北市中和區建一路時，因疲勞駕駛打瞌睡，不慎失控撞上...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('陳男', 3), ('分隔島', 2), ('原因', 2), ('事故', 2), ...
# tokens          ['陳姓', '男子', '今天', '凌晨', '3時', '許', '駕駛', '自',...
# tokens_v2       ['陳姓', '男子', '駕駛', '新北市', '中和區', '建一路', '撞上', ...
# entities        [NerToken(word='陳', ner='PERSON', idx=(0, 1)),...
# token_pos       [('陳姓', 'Nb'), ('男子', 'Na'), ('今天', 'Nd'), ('凌...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 12, dtype: object
# Error at row 13: no such table: news_data2
# item_id                                        society_20250327_4
# date                                                   2025-03-27
# category                                                       社會
# title                                      竹市4月女嬰在托嬰中心疑趴睡窒息 今搶救不治
# content         新竹市3月11日傳出東區某五星評價的托嬰中心內有4個月大的女嬰疑因趴睡40分窒息，經送醫急救...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('中心', 10), ('女嬰', 10), ('市府', 6), ('社會處', 5)...
# tokens          ['新竹市', '3月', '11日', '傳出', '東區', '某', '五星', '評...
# tokens_v2       ['新竹市', '傳出', '東區', '五星', '評價', '托嬰', '中心', '女...
# entities        [NerToken(word='新竹市', ner='GPE', idx=(0, 3)), ...
# token_pos       [('新竹市', 'Nc'), ('3月', 'Nd'), ('11日', 'Nd'), (...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 13, dtype: object
# Error at row 14: no such table: news_data2
# item_id                                        society_20250327_5
# date                                                   2025-03-27
# category                                                       社會
# title                                      拿錯別人「熊大」行李 7旬婦返國後半夜才發現
# content         烏日區74歲陳婦與家人至日本名古屋開心旅遊，16日晚上10點抵達桃園國際機場，返回台中已半夜...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('陳婦', 7), ('行李箱', 6), ('熊大', 5), ('家人', 4), ...
# tokens          ['烏日區', '74', '歲', '陳婦', '與', '家人', '至', '日本',...
# tokens_v2       ['烏日區', '陳婦', '家人', '日本', '桃園', '國際', '機場', '台...
# entities        [NerToken(word='烏日區', ner='LOC', idx=(0, 3)), ...
# token_pos       [('烏日區', 'Nc'), ('74', 'Neu'), ('歲', 'Nf'), ('...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 14, dtype: object
# Error at row 15: no such table: news_data2
# item_id                                        society_20250327_6
# date                                                   2025-03-27
# category                                                       社會
# title                                   擋下竹聯幫在立院餐敘 卓榮泰：關注後續發展嚴查嚴辦
# content         統促黨總裁「白狼」張安樂昨原擬在立法院康園餐廳票選竹聯幫幫主，行政院長卓榮泰第一時間要求內政...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('卓榮泰', 4), ('單位', 3), ('行為', 3), ('康園', 2), ...
# tokens          ['統促黨', '總裁', '「', '白狼', '」', '張安樂', '昨', '原擬'...
# tokens_v2       ['統促黨', '總裁', '張安樂', '立法院', '康園', '餐廳', '票選', ...
# entities        [NerToken(word='統促黨', ner='ORG', idx=(0, 3)), ...
# token_pos       [('統促黨', 'Nb'), ('總裁', 'Na'), ('「', 'PARENTHES...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 15, dtype: object
# Error at row 16: no such table: news_data2
# item_id                                        society_20250327_7
# date                                                   2025-03-27
# category                                                       社會
# title                                           男子騎車自撞路邊金爐 倒地傷重不治
# content         59歲徐姓男子今天早上6點多騎乘機車，行經台1線北上方向130.9公里、苗栗縣通霄鎮通灣里路...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('徐男', 5), ('警方', 3), ('騎乘', 2), ('機車', 2), (...
# tokens          ['59', '歲', '徐姓', '男子', '今天', '早上', '6點', '多',...
# tokens_v2       ['徐姓', '男子', '騎乘', '機車', '台1線', '方向', '苗栗縣', '...
# entities        [NerToken(word='59歲', ner='DATE', idx=(0, 3)),...
# token_pos       [('59', 'Neu'), ('歲', 'Nf'), ('徐姓', 'Nb'), ('男...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 16, dtype: object
# Error at row 17: no such table: news_data2
# item_id                                        society_20250327_8
# date                                                   2025-03-27
# category                                                       社會
# title                                   害張宏年一家「鉛中毒」 盛唐中醫呂志霖二審改判5年
# content         前台中市議會議長張宏年、議員張彥彤一家四口2020年爆發鉛中毒案，經查被害人多達38人；20...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('呂志霖', 9), ('硃砂', 9), ('徒刑', 7), ('歐國樑', 7),...
# tokens          ['前', '台中', '市議會', '議長', '張宏年', '、', '議員', '張彥...
# tokens_v2       ['台中', '市議會', '議長', '張宏年', '議員', '張彥彤', '中毒', ...
# entities        [NerToken(word='台中市', ner='GPE', idx=(1, 4)), ...
# token_pos       [('前', 'Nes'), ('台中', 'Nc'), ('市議會', 'Nc'), ('...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 17, dtype: object
# Error at row 18: no such table: news_data2
# item_id                                        society_20250327_9
# date                                                   2025-03-27
# category                                                       社會
# title                                 工人寺廟擴建工程死亡 老闆竟要求家屬代賠百萬職災補償金
# content         陳姓男子受雇到高雄鳥松區某寺廟進行擴建工程，施工期間不慎意外死亡，工程行賠給死者家屬400萬...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('家屬', 12), ('工程行', 11), ('勞保局', 6), ('工程', 4...
# tokens          ['陳姓', '男子', '受雇', '到', '高雄', '鳥松區', '某', '寺廟'...
# tokens_v2       ['陳姓', '男子', '高雄', '鳥松區', '寺廟', '進行', '工程', '期...
# entities        [NerToken(word='陳', ner='PERSON', idx=(0, 1)),...
# token_pos       [('陳姓', 'Nb'), ('男子', 'Na'), ('受雇', 'VI'), ('到...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 18, dtype: object
# Error at row 19: no such table: news_data2
# item_id                                       society_20250327_10
# date                                                   2025-03-27
# category                                                       社會
# title                                  兒子落入假投資圈套被騙到沒錢 還要老媽去銀行幫忙匯款
# content         60歲王姓婦人的兒子，落入詐騙集團假投資陷阱，他自己被騙以後，積蓄清空，但他仍不自知，甚至還...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('兒子', 6), ('集團', 6), ('銀行', 5), ('行員', 4), (...
# tokens          ['60', '歲', '王姓', '婦人', '的', '兒子', '，', '落入', ...
# tokens_v2       ['王姓', '婦人', '兒子', '集團', '投資', '陷阱', '積蓄', '母親...
# entities        [NerToken(word='60歲', ner='DATE', idx=(0, 3)),...
# token_pos       [('60', 'Neu'), ('歲', 'Nf'), ('王姓', 'Nb'), ('婦...
# link            https://news.ltn.com.tw/news/society/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 19, dtype: object
# Error at row 20: no such table: news_data2
# item_id                                           life_20250327_1
# date                                                   2025-03-27
# category                                                       生活
# title                            114年大學入學個人申請一階放榜 竹北高中頂大熱門科系錄取率亮眼
# content         114年大學入學個人申請第一階段今（27）日放榜，國立竹北高中表示，今年個人申請共2316個...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('大學', 9), ('人次', 7), ('通過', 6), ('學生', 4), (...
# tokens          ['114年', '大學', '入學', '個人', '申請', '第一', '階段', '...
# tokens_v2       ['大學', '階段', '竹北', '高中', '通過', '通過', '電資學群', '...
# entities        [NerToken(word='114年', ner='DATE', idx=(0, 4))...
# token_pos       [('114年', 'Neu'), ('大學', 'Nc'), ('入學', 'VA'), ...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 20, dtype: object
# Error at row 21: no such table: news_data2
# item_id                                           life_20250327_2
# date                                                   2025-03-27
# category                                                       生活
# title                                        白沙屯拱天宮進香報名首日 中午已達2萬人
# content         苗栗縣通霄鎮拱天宮白沙屯媽祖徒步前往雲林縣北港朝天宮進香，是全國矚目的宗教盛事，今天首日受理...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('信眾', 5), ('人潮', 4), ('拱天宮', 3), ('排到', 3), ...
# tokens          ['苗栗縣', '通霄鎮', '拱天宮', '白沙屯媽祖', '徒步', '前往', '雲林...
# tokens_v2       ['苗栗縣', '通霄鎮', '拱天宮', '白沙屯媽祖', '雲林縣', '北港', '朝...
# entities        [NerToken(word='苗栗縣', ner='GPE', idx=(0, 3)), ...
# token_pos       [('苗栗縣', 'Nc'), ('通霄鎮', 'Nc'), ('拱天宮', 'Nc'), ...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 21, dtype: object
# Error at row 22: no such table: news_data2
# item_id                                           life_20250327_3
# date                                                   2025-03-27
# category                                                       生活
# title                                      兒童節、清明節休假日出勤 雇主應加給1日工資
# content         下週就是清明節4天連續假期，新北市勞工局提醒，兒童節及民族掃墓節皆為勞基法規定的休假日，雇主...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('勞工', 11), ('勞工局', 4), ('民族', 4), ('規定', 4),...
# tokens          ['下', '週', '就是', '清明節', '4', '天', '連續', '假期', ...
# tokens_v2       ['假期', '勞工局', '民族', '節皆', '勞基法', '規定', '雇主', '...
# entities        [NerToken(word='下週', ner='DATE', idx=(0, 2)), ...
# token_pos       [('下', 'Nes'), ('週', 'Nf'), ('就是', 'D'), ('清明節...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 22, dtype: object
# Error at row 23: no such table: news_data2
# item_id                                           life_20250327_4
# date                                                   2025-03-27
# category                                                       生活
# title                            「舊鞋救命」活動明起台南登場  台積電慈善基金會加入送暖非洲行列
# content         為促進二手物資循環再利用並響應國際援助，台南市政府攜手舊鞋救命國際基督關懷協會、企業、學校等...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('活動', 9), ('物資', 6), ('募集', 5), ('張淑芬', 4), ...
# tokens          ['為', '促進', '二手', '物資', '循環', '再', '利用', '並', ...
# tokens_v2       ['物資', '利用', '響應', '國際', '援助', '台南市政府', '國際', ...
# entities        [NerToken(word='舊鞋救命國際基督關懷協會', ner='ORG', idx=...
# token_pos       [('為', 'P'), ('促進', 'VK'), ('二手', 'A'), ('物資',...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 23, dtype: object
# Error at row 24: no such table: news_data2
# item_id                                           life_20250327_5
# date                                                   2025-03-27
# category                                                       生活
# title                                  全台首輛AI數位列車進駐北捷   偵測行維護乘客安全
# content         台北捷運攜手電腦公司宏基合作打造安全車廂環境，全台第一輛AI數位列車今（27）日於淡水信義線...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('列車', 7), ('車廂', 6), ('偵測', 5), ('宏基', 4), (...
# tokens          ['台北', '捷運', '攜手', '電腦', '公司', '宏基', '合作', '打造...
# tokens_v2       ['台北', '捷運', '電腦', '公司', '宏基', '打造', '車廂', '環境...
# entities        [NerToken(word='宏基', ner='ORG', idx=(10, 12)),...
# token_pos       [('台北', 'Nc'), ('捷運', 'Na'), ('攜手', 'D'), ('電腦...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 24, dtype: object
# Error at row 25: no such table: news_data2
# item_id                                           life_20250327_6
# date                                                   2025-03-27
# category                                                       生活
# title                                  新北新板特區百餘坪土地價值6.7億元 無人辦繼承登記
# content         新北市今年逾期未辦理繼承登記的不動產，4月1日起將由各地政事務所公告至6月30日，統計被繼承...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('繼承', 11), ('辦理', 6), ('登記', 6), ('土地', 4), ...
# tokens          ['新北市', '今年', '逾期', '未', '辦理', '繼承', '登記', '的'...
# tokens_v2       ['新北市', '辦理', '繼承', '登記', '不動產', '地政', '事務所', ...
# entities        [NerToken(word='新北市', ner='GPE', idx=(0, 3)), ...
# token_pos       [('新北市', 'Nb'), ('今年', 'Nd'), ('逾期', 'VH'), ('...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 25, dtype: object
# Error at row 26: no such table: news_data2
# item_id                                           life_20250327_7
# date                                                   2025-03-27
# category                                                       生活
# title                                  政院拍板健康台灣深耕計畫 5年489億元補助醫療機構
# content         行政院會今天通過「健康台灣深耕計畫（2025—2029年）」，預計5年投注489億元的力拚「...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('醫療', 10), ('計畫', 9), ('衛福部', 4), ('體系', 3),...
# tokens          ['行政', '院會', '今天', '通過', '「', '健康', '台灣', '深耕'...
# tokens_v2       ['行政', '院會', '通過', '台灣', '計畫', '投注', '力拚', '醫療...
# entities        [NerToken(word='2025—2029年', ner='DATE', idx=(...
# token_pos       [('行政', 'Nc'), ('院會', 'Nc'), ('今天', 'Nd'), ('通...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 26, dtype: object
# Error at row 27: no such table: news_data2
# item_id                                           life_20250327_8
# date                                                   2025-03-27
# category                                                       生活
# title                               準公托評鑑未過影響1.5萬托育補助 衛福部3個月內研議對策
# content         有民眾因原本送托小孩的準公共化托嬰中心未能符合評鑑標準，必須更換托嬰中心，造成原本每月可請領...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('中心', 12), ('托育', 11), ('衛福部', 6), ('家長', 4)...
# tokens          ['有', '民眾', '因', '原本', '送托', '小孩', '的', '準', '...
# tokens_v2       ['民眾', '小孩', '中心', '標準', '更換', '中心', '請領', '托育...
# entities        [NerToken(word='托嬰中心', ner='FAC', idx=(32, 36)...
# token_pos       [('有', 'V_2'), ('民眾', 'Na'), ('因', 'P'), ('原本'...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 27, dtype: object
# Error at row 28: no such table: news_data2
# item_id                                           life_20250327_9
# date                                                   2025-03-27
# category                                                       生活
# title                             墾丁民宿哄抬一晚從895元漲至7980元  屏縣府開罰要求停業
# content         國內旅遊市場低迷，墾丁觀光今年以來備受衝擊，但清明4天連假即將登場，挾著墾丁年度獨立音樂盛事...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('業者', 8), ('縣府', 7), ('墾丁', 6), ('台灣祭', 6), ...
# tokens          ['國內', '旅遊', '市場', '低迷', '，', '墾丁', '觀光', '今年'...
# tokens_v2       ['國內', '市場', '墾丁', '衝擊', '墾丁', '年度', '音樂', '盛事...
# entities        [NerToken(word='墾丁觀光', ner='ORG', idx=(9, 13))...
# token_pos       [('國內', 'Nc'), ('旅遊', 'Nv'), ('市場', 'Nc'), ('低...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 28, dtype: object
# Error at row 29: no such table: news_data2
# item_id                                          life_20250327_10
# date                                                   2025-03-27
# category                                                       生活
# title                                  十三行小志工長大當博物館員 八里女孩分享獨家在地玩法
# content         新北市立十三行博物館員張媛茹從小在八里成長，國中二年級成為博物館小志工，如今她將童年的感動化...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('八里', 7), ('路線', 6), ('地圖', 5), ('張媛茹', 4), ...
# tokens          ['新北', '市立', '十三行', '博物館員', '張媛茹', '從小', '在', ...
# tokens_v2       ['新北', '十三行', '博物館員', '張媛茹', '八里', '國中', '二年級'...
# entities        [NerToken(word='張媛茹', ner='PERSON', idx=(11, 1...
# token_pos       [('新北', 'Nc'), ('市立', 'A'), ('十三行', 'Nc'), ('博...
# link            https://news.ltn.com.tw/news/life/breakingnews...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 29, dtype: object
# Error at row 30: no such table: news_data2
# item_id                                          world_20250327_1
# date                                                   2025-03-27
# category                                                       國際
# title                                   兒童戲水區活春宮 澳洲怪男竟要收錢：這不是免費表演
# content         澳洲昆士蘭州黃金海岸的伊恩迪普爾潟湖（Ian Dipple Lagoon）有沙灘與兒童戲水區...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('男子', 3), ('親子', 2), ('男女', 2), ('水區', 2), (...
# tokens          ['澳洲', '昆士蘭州', '黃金海岸', '的', '伊恩迪普爾', '潟湖', '（'...
# tokens_v2       ['澳洲', '昆士蘭州', '黃金海岸', '伊恩迪普爾', '潟湖', '沙灘', '兒...
# entities        [NerToken(word='澳洲', ner='GPE', idx=(0, 2)), N...
# token_pos       [('澳洲', 'Nc'), ('昆士蘭州', 'Nc'), ('黃金海岸', 'Nc'),...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 30, dtype: object
# Error at row 31: no such table: news_data2
# item_id                                          world_20250327_2
# date                                                   2025-03-27
# category                                                       國際
# title                                    衣服脫了被搶劫！女全裸大街追賊 旁觀人看傻不幫忙
# content         墨西哥莫雷洛斯州庫埃納瓦卡市（Cuernavaca）街頭日前出現詭異一幕。一名全裸女子在街上...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('男子', 6), ('女子', 4), ('墨西哥', 3), ('伸出', 3), ...
# tokens          ['墨西哥', '莫雷洛斯州', '庫埃納瓦卡市', '（', 'Cuernavaca', ...
# tokens_v2       ['墨西哥', '莫雷洛斯州', '庫埃納瓦卡市', '街頭', '女子', '男子', '...
# entities        [NerToken(word='墨西哥', ner='GPE', idx=(0, 3)), ...
# token_pos       [('墨西哥', 'Nc'), ('莫雷洛斯州', 'Nb'), ('庫埃納瓦卡市', 'N...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 31, dtype: object
# Error at row 32: no such table: news_data2
# item_id                                          world_20250327_3
# date                                                   2025-03-27
# category                                                       國際
# title                              Signal之亂延燒！川普團隊滅火變提油救火 盟友也看不下去
# content         美國川普政府高層透過加密通訊軟體「Signal」討論軍事機密，卻誤將記者拉進群組，這場政治危...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('瓦爾茲', 8), ('白宮', 6), ('川普', 4), ('記者', 3), ...
# tokens          ['美國', '川普', '政府', '高層', '透過', '加密', '通訊', '軟體...
# tokens_v2       ['美國', '川普', '政府', '高層', '通訊', '軟體', '軍事', '機密...
# entities        [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('美國', 'Nc'), ('川普', 'Nb'), ('政府', 'Na'), ('高...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 32, dtype: object
# Error at row 33: no such table: news_data2
# item_id                                          world_20250327_4
# date                                                   2025-03-27
# category                                                       國際
# title                                  海王星「幽靈極光」現形 韋伯望遠鏡還發現大氣異常降溫
# content         韋伯太空望遠鏡（JWST）近日首度拍攝到海王星的神秘極光，驗證了36年前「航海家二號」（Vo...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('海王星', 8), ('極光', 7), ('韋伯', 4), ('溫度', 4), ...
# tokens          ['韋伯', '太空', '望遠鏡', '（', 'JWST', '）', '近日', '首...
# tokens_v2       ['韋伯', '太空', '望遠鏡', '拍攝到', '海王星', '極光', '航海家',...
# entities        [NerToken(word='JWST', ner='ORG', idx=(8, 12))...
# token_pos       [('韋伯', 'Nb'), ('太空', 'Na'), ('望遠鏡', 'Na'), ('...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 33, dtype: object
# Error at row 34: no such table: news_data2
# item_id                                          world_20250327_5
# date                                                   2025-03-27
# category                                                       國際
# title                                        南韓野火持續蔓延 已26死、30人輕重傷
# content         南韓東南部野火造成多人死傷，南韓中央災難安全對策本部27日表示，截至今早6點，森林大火已造成...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('慶尚', 4), ('南韓', 3), ('中央', 3), ('災難', 3), (...
# tokens          ['南韓', '東南部', '野火', '造成', '多', '人', '死傷', '，',...
# tokens_v2       ['南韓', '野火', '南韓', '中央', '災難', '對策', '本部', '森林...
# entities        [NerToken(word='南韓', ner='GPE', idx=(0, 2)), N...
# token_pos       [('南韓', 'Nc'), ('東南部', 'Ncd'), ('野火', 'Na'), (...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 34, dtype: object
# Error at row 35: no such table: news_data2
# item_id                                          world_20250327_6
# date                                                   2025-03-27
# category                                                       國際
# title                          「綁架」影片曝光！美移民局強押土耳其博士生 民權團體怒轟「政治迫害」
# content         美國聯邦移民局（ICE）近日在麻薩諸塞州索莫維爾突襲拘留土耳其籍博士生歐澤爾（Rumeysa...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('歐澤爾', 7), ('巴勒斯坦', 6), ('釋放', 6), ('索莫維爾', ...
# tokens          ['美國', '聯邦', '移民局', '（', 'ICE', '）', '近日', '在'...
# tokens_v2       ['美國', '聯邦', '移民局', '麻薩諸塞州', '索莫維爾', '突襲', '拘留...
# entities        [NerToken(word='美國聯邦移民局', ner='ORG', idx=(0, 7...
# token_pos       [('美國', 'Nc'), ('聯邦', 'Na'), ('移民局', 'Nc'), ('...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 35, dtype: object
# Error at row 36: no such table: news_data2
# item_id                                          world_20250327_7
# date                                                   2025-03-27
# category                                                       國際
# title                                    薛瑞福建議美軍續訓台灣軍隊 助台推進應用無人科技
# content         美國國防部前官員薛瑞福今天在國會指出，美台軍事合作已經進入「一度是禁忌」的領域，例如美軍協訓...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('美國', 15), ('台灣', 15), ('薛瑞福', 8), ('領域', 5)...
# tokens          ['美國', '國防部', '前', '官員', '薛瑞福', '今天', '在', '國會...
# tokens_v2       ['美國', '國防部', '官員', '薛瑞福', '國會', '軍事', '禁忌', '...
# entities        [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('美國', 'Nc'), ('國防部', 'Nc'), ('前', 'Nes'), ('...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 36, dtype: object
# Error at row 37: no such table: news_data2
# item_id                                          world_20250327_8
# date                                                   2025-03-27
# category                                                       國際
# title                                警告非法移民！美國土安全部長進「世界最恐怖監獄」霸氣喊話
# content         美國國土安全部長諾姆（Kristi Noem）近日造訪薩爾瓦多的「恐怖主義監禁中心」（CEC...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('薩爾瓦多', 8), ('監獄', 6), ('美國', 4), ('諾姆', 4),...
# tokens          ['美國', '國土', '安全', '部長', '諾姆', '（', 'Kristi ',...
# tokens_v2       ['美國', '國土', '部長', '諾姆', '造訪', '薩爾瓦多', '恐怖', '...
# entities        [NerToken(word='美國國土安全部長', ner='ORG', idx=(0, ...
# token_pos       [('美國', 'Nc'), ('國土', 'Na'), ('安全', 'VH'), ('部...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 37, dtype: object
# Error at row 38: no such table: news_data2
# item_id                                          world_20250327_9
# date                                                   2025-03-27
# category                                                       國際
# title                                     馬克宏會晤澤倫斯基 加碼軍援烏克蘭籲俄羅斯停火
# content         歐洲援烏峰會前夕，烏克蘭總統澤倫斯基今天抵法國，兩國元首晚間先行會晤。馬克宏在會後記者會中宣...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('俄羅斯', 13), ('烏克蘭', 12), ('歐洲', 9), ('馬克宏', ...
# tokens          ['歐洲', '援烏', '峰會', '前夕', '，', '烏克蘭', '總統', '澤倫...
# tokens_v2       ['歐洲', '援烏', '峰會', '烏克蘭', '總統', '澤倫斯基', '法國', ...
# entities        [NerToken(word='歐洲', ner='LOC', idx=(0, 2)), N...
# token_pos       [('歐洲', 'Nc'), ('援烏', 'Nc'), ('峰會', 'Na'), ('前...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 38, dtype: object
# Error at row 39: no such table: news_data2
# item_id                                         world_20250327_10
# date                                                   2025-03-27
# category                                                       國際
# title                                 美高層「群聊洩密」他最坦率？魯比歐直言：有人犯了大錯！
# content         美國知名刊物「大西洋月刊」（The Atlantic）總編輯高德柏格（Jeffrey Gol...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('美國', 7), ('魯比歐', 5), ('記者', 4), ('葉門', 3), ...
# tokens          ['美國', '知名', '刊物', '「', '大西洋', '月刊', '」', '（',...
# tokens_v2       ['美國', '刊物', '大西洋', '月刊', '總編輯', '高德柏格', '美國',...
# entities        [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('美國', 'Nc'), ('知名', 'VH'), ('刊物', 'Na'), ('「...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 39, dtype: object
# Error at row 40: no such table: news_data2
# item_id                                        novelty_20250323_1
# date                                                   2025-03-23
# category                                                       蒐集
# title                                   英男「靠1招」搭整年火車 自曝：合法省下逾4.2萬
# content         英國的火車公司，會根據列車的延誤時間，提供乘客不同程度的退款。不過，就有一名男子巧妙利用了這...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('火車', 7), ('艾德', 5), ('英國', 3), ('公司', 3), (...
# tokens          ['英國', '的', '火車', '公司', '，', '會', '根據', '列車', ...
# tokens_v2       ['英國', '火車', '公司', '列車', '時間', '乘客', '程度', '退款...
# entities        [NerToken(word='英國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('英國', 'Nc'), ('的', 'DE'), ('火車', 'Na'), ('公司...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 40, dtype: object
# Error at row 41: no such table: news_data2
# item_id                                        novelty_20250323_2
# date                                                   2025-03-23
# category                                                       蒐集
# title                                    日本呆萌小食蟻獸「爬樹賞櫻」 粉嫩畫面融化一票人
# content         隨著氣溫逐漸回溫，日本多地陸續迎接粉嫩櫻花，一名網友分享，日前到靜岡縣一間動物園參觀時，不僅...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('食蟻獸', 4), ('櫻花', 3), ('網友', 3), ('畫面', 3), ...
# tokens          ['隨著', '氣溫', '逐漸', '回溫', '，', '日本', '多', '地', ...
# tokens_v2       ['氣溫', '日本', '迎接', '櫻花', '網友', '靜岡縣', '動物園', '...
# entities        [NerToken(word='日本', ner='GPE', idx=(9, 11)), ...
# token_pos       [('隨著', 'P'), ('氣溫', 'Na'), ('逐漸', 'D'), ('回溫'...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 41, dtype: object
# Error at row 42: no such table: news_data2
# item_id                                        novelty_20250323_3
# date                                                   2025-03-23
# category                                                       蒐集
# title                                  吃到ㄎ一ㄤ了？ 日本玳瑁貓獨特「嗑草」神情逗樂百萬人
# content         不少飼主會給喵星人餵食適量的「貓草」，不僅可以維持牠們的腸胃健康，還有助於減少異物啃咬、放鬆...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('貓草', 5), ('神情', 3), ('網友', 3), ('照片', 3), (...
# tokens          ['不少', '飼主', '會', '給', '喵星人', '餵食', '適量', '的',...
# tokens_v2       ['飼主', '喵星人', '餵食', '貓草', '腸胃', '異物', '壓力', '日...
# entities        [NerToken(word='日本', ner='GPE', idx=(50, 52)),...
# token_pos       [('不少', 'Neqa'), ('飼主', 'Na'), ('會', 'D'), ('給...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 42, dtype: object
# Error at row 43: no such table: news_data2
# item_id                                        novelty_20250323_4
# date                                                   2025-03-23
# category                                                       蒐集
# title                                        羊駝兄弟化身「白衣天使」巡房 超萌畫面曝
# content         不再只靠醫療治病！近日一段網路影片受關注，影片中醫療人員帶著兩隻羊駝走在安養院走廊巡房，兩隻...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('羊駝', 7), ('安養院', 4), ('影片', 3), ('人員', 2), ...
# tokens          ['不再', '只', '靠', '醫療', '治病', '！', '近日', '一', '...
# tokens_v2       ['醫療', '網路', '影片', '影片', '人員', '羊駝', '安養院', '走...
# entities        [NerToken(word='近日', ner='DATE', idx=(9, 11)),...
# token_pos       [('不再', 'D'), ('只', 'Da'), ('靠', 'P'), ('醫療', ...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 43, dtype: object
# Error at row 44: no such table: news_data2
# item_id                                        novelty_20250323_5
# date                                                   2025-03-23
# category                                                       蒐集
# title                              狂！美喬治亞州籃球賽打了121小時、比分破萬 創金氏世界紀錄
# content         太狂了！美國喬治亞州亞特蘭大非營利組織「男性反對性交易（MOST）」，由23名成員分成2隊進...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('臉書', 3), ('性交易', 2), ('體育館', 2), ('球員', 2),...
# tokens          ['太', '狂', '了', '！', '美國', '喬治亞州', '亞特蘭大', '非'...
# tokens_v2       ['美國', '喬治亞州', '亞特蘭大', '組織', '男性', '反對', '性交易'...
# entities        [NerToken(word='喬治亞州亞特蘭大非營利組織', ner='ORG', idx...
# token_pos       [('太', 'Dfa'), ('狂', 'VH'), ('了', 'T'), ('！', ...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 44, dtype: object
# Error at row 45: no such table: news_data2
# item_id                                        novelty_20250319_6
# date                                                   2025-03-19
# category                                                       蒐集
# title                                  中國年輕人壓力山大！ 「玉米」成紓壓神器單價破3萬元
# content         中國年輕人近期興起一種新的解壓文化「盤玉米」，將特別培育的「文玩玉米」當作手中玩物，透過反覆...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('玉米', 8), ('中國', 3), ('文玩', 3), ('文玩玉米', 3),...
# tokens          ['中國', '年輕人', '近期', '興起', '一', '種', '新', '的', ...
# tokens_v2       ['中國', '年輕人', '興起', '解壓', '文化', '盤玉米', '培育', '...
# entities        [NerToken(word='中國', ner='NORP', idx=(0, 2)), ...
# token_pos       [('中國', 'Nc'), ('年輕人', 'Na'), ('近期', 'Nd'), ('...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 45, dtype: object
# Error at row 46: no such table: news_data2
# item_id                                        novelty_20250319_7
# date                                                   2025-03-19
# category                                                       蒐集
# title                                      摩鐵床底下驚見「鱷魚」 經理嚇傻：牠超友善！
# content         美國密西根州希博伊根郡（Cheboygan）一家汽車旅館近日發生驚人一幕，打掃人員竟在床底下...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('汽車', 3), ('旅館', 3), ('鱷魚', 3), ('飼主', 3), (...
# tokens          ['美國', '密西根州', '希博伊根郡', '（', 'Cheboygan', '）',...
# tokens_v2       ['美國', '密西根州', '希博伊根郡', '汽車', '旅館', '打掃', '人員'...
# entities        [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('美國', 'Nc'), ('密西根州', 'Nc'), ('希博伊根郡', 'Nc')...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 46, dtype: object
# Error at row 47: no such table: news_data2
# item_id                                        novelty_20250318_8
# date                                                   2025-03-18
# category                                                       蒐集
# title                               呆萌柯基熱衷當「冰箱守門員」 日本飼主嘆︰牠超愛躺在那睡覺
# content         一些毛小孩喜歡無時無刻黏著飼主，雖然能讓飼主感受到牠們的愛，卻也會來帶一點不便。日本一名飼主...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('冰箱', 6), ('網友', 4), ('飼主', 3), ('日本', 2), (...
# tokens          ['一些', '毛小孩', '喜歡', '無時', '無刻', '黏著', '飼主', '，...
# tokens_v2       ['毛小孩', '黏著', '飼主', '飼主', '日本', '飼主', '寵物', '柯...
# entities        [NerToken(word='日本', ner='GPE', idx=(40, 42)),...
# token_pos       [('一些', 'Neqa'), ('毛小孩', 'Na'), ('喜歡', 'VK'), ...
# link            https://news.ltn.com.tw/news/novelty/breakingn...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/03...
# Name: 47, dtype: object
# Error at row 48: no such table: news_data2
# item_id                                        novelty_20250318_9
# date                                                   2025-03-18
# category                                                       蒐集
# title                                   這是鐵路不是「馬路」！ 美國火車因馬兒擋道被迫停駛
# content         這不是馬走的路！美國緬因州拉格蘭奇（Lagrange）1處鐵路橋，近來有1匹馬兒突然闖越鐵軌...
# sentiment                                                      暫無
# ...
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 471, dtype: object
# Error at row 472: no such table: news_data2
# item_id                                           life_20250411_5
# date                                                   2025-04-11
# category                                                       生活
# title                                               後龍苗9線道路損壞 將重鋪
# content         苗栗縣苗九線為後龍鎮重要南北幹道，因長期使用，出現道路損壞狀況，經苗栗縣府提報改善，獲中央納...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('道路', 4), ('苗九線', 2), ('路面', 2), ('苗栗縣', 1),...
# tokens          ['苗栗縣', '苗九線', '為', '後龍鎮', '重要', '南北', '幹道', '...
# tokens_v2       ['苗栗縣', '苗九線', '後龍鎮', '幹道', '使用', '道路', '損壞', ...
# entities        [NerToken(word='後龍鎮', ner='GPE', idx=(7, 10)),...
# token_pos       [('苗栗縣', 'Nc'), ('苗九線', 'Nc'), ('為', 'VG'), ('...
# link              https://news.ltn.com.tw/news/life/paper/1701154
# photo_link                                                    NaN
# Name: 472, dtype: object
# Error at row 473: no such table: news_data2
# item_id                                           life_20250411_6
# date                                                   2025-04-11
# category                                                       生活
# title                                           桃園3業者長照專車 議員疑浮報請款
# content         桃園市政府現有一四四輛長照專車，與十四家運輸業者簽約提供載送服務，使用者預約搭乘按計程車費率...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('里程數', 9), ('專車', 5), ('使用', 4), ('長照', 4), ...
# tokens          ['桃園市政府', '現有', '一四四', '輛', '長照', '專車', '，', '...
# tokens_v2       ['桃園市政府', '專車', '運輸', '業者', '載送', '服務', '使用', ...
# entities        [NerToken(word='桃園市政府', ner='ORG', idx=(0, 5))...
# token_pos       [('桃園市政府', 'Nc'), ('現有', 'A'), ('一四四', 'Neu'),...
# link              https://news.ltn.com.tw/news/life/paper/1701122
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 473, dtype: object
# Error at row 474: no such table: news_data2
# item_id                                           life_20250411_7
# date                                                   2025-04-11
# category                                                       生活
# title                                             黑熊受困 高雄首例救援成功野放
# content         林業及自然保育署屏東分署九日接獲桃源區梅山部落顏姓族人通報，在梅山農路邊坡發現台灣黑熊受困陷...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('黑熊', 6), ('屏東', 3), ('分署', 3), ('部落', 3), (...
# tokens          ['林業', '及', '自然', '保育署', '屏東', '分署', '九日', '接獲...
# tokens_v2       ['林業', '自然', '保育署', '屏東', '分署', '接獲', '桃源區', '...
# entities        [NerToken(word='林業及自然保育署屏東分署', ner='ORG', idx=...
# token_pos       [('林業', 'Na'), ('及', 'Caa'), ('自然', 'Na'), ('保...
# link              https://news.ltn.com.tw/news/life/paper/1701160
# photo_link                                                    NaN
# Name: 474, dtype: object
# Error at row 475: no such table: news_data2
# item_id                                           life_20250411_8
# date                                                   2025-04-11
# category                                                       生活
# title                                   Skytrax百大機場評比 桃機行李運送 全球第一
# content         英國非營利獨立調查機構Skytrax公布2025年World Airport Awards（...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('機場', 7), ('全球', 2), ('英國', 1), ('機構', 1), (...
# tokens          ['英國', '非', '營利', '獨立', '調查', '機構', 'Skytrax',...
# tokens_v2       ['英國', '機構', '公布', '世界', '機場', '大獎', '結果', '機場...
# entities        [NerToken(word='英國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('英國', 'Nc'), ('非', 'A'), ('營利', 'VH'), ('獨立'...
# link              https://news.ltn.com.tw/news/life/paper/1701031
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 475, dtype: object
# Error at row 476: no such table: news_data2
# item_id                                           life_20250411_9
# date                                                   2025-04-11
# category                                                       生活
# title                                 航空城優先產專區D基地》傳得標廠商無力繳款 將重新招標
# content         桃園市政府二○二二年標售桃園航空城優先產業專區土地，目前進入第三期繳款，傳出D基地得標廠商力...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('基地', 8), ('土地', 7), ('標售', 3), ('市府', 3), (...
# tokens          ['桃園', '市政府', '二○二二年', '標售', '桃園', '航空城', '優先'...
# tokens_v2       ['桃園', '市政府', '標售', '桃園', '航空城', '產業', '專區', '...
# entities        [NerToken(word='桃園市政府', ner='ORG', idx=(0, 5))...
# token_pos       [('桃園', 'Nc'), ('市政府', 'Nc'), ('二○二二年', 'Nd'),...
# link              https://news.ltn.com.tw/news/life/paper/1701125
# photo_link                                                    NaN
# Name: 476, dtype: object
# Error at row 477: no such table: news_data2
# item_id                                          life_20250411_10
# date                                                   2025-04-11
# category                                                       生活
# title                                           新北街舞大賽報名 前3名送韓國參賽
# content         由新北市府主辦的「國際街舞大賽」，今年賽事即日起至七月十六日受理報名，副市長劉和然昨天表示，...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('街舞', 5), ('獎金', 5), ('舞風', 5), ('冠軍', 4), (...
# tokens          ['由', '新北', '市府', '主辦', '的', '「', '國際', '街舞', ...
# tokens_v2       ['新北', '市府', '主辦', '國際', '街舞', '大賽', '賽事', '受理...
# entities        [NerToken(word='國際街舞大賽', ner='EVENT', idx=(9, ...
# token_pos       [('由', 'P'), ('新北', 'Nc'), ('市府', 'Nc'), ('主辦'...
# link              https://news.ltn.com.tw/news/life/paper/1701070
# photo_link                                                    NaN
# Name: 477, dtype: object
# Error at row 478: no such table: news_data2
# item_id                                          world_20250411_1
# date                                                   2025-04-11
# category                                                       國際
# title                                            打造格陵蘭 挺川科技富豪躍躍欲試
# content         路透十日引述三名知情人士獨家披露，隨著美國川普政府加大從丹麥手中拿下其海外自治領地格陵蘭島的...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('美國', 7), ('格陵蘭', 6), ('川普', 5), ('霍爾里', 5),...
# tokens          ['路透', '十日', '引述', '三', '名', '知情', '人士', '獨家',...
# tokens_v2       ['路透', '引述', '知情', '人士', '美國', '川普', '政府', '加大...
# entities        [NerToken(word='十日', ner='DATE', idx=(2, 4)), ...
# token_pos       [('路透', 'Na'), ('十日', 'Nd'), ('引述', 'VC'), ('三...
# link             https://news.ltn.com.tw/news/world/paper/1701131
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 478, dtype: object
# Error at row 479: no such table: news_data2
# item_id                                          world_20250411_2
# date                                                   2025-04-11
# category                                                       國際
# title                                         澤倫斯基揭中國人為俄作戰 掌握155人
# content         烏克蘭軍隊在烏國東部俘虜兩名隨俄羅斯軍隊作戰的中國士兵後，總統澤倫斯基九日進一步透露，烏國掌...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('中國', 15), ('俄軍', 11), ('公民', 10), ('烏國', 6)...
# tokens          ['烏克蘭', '軍隊', '在', '烏國', '東部', '俘虜', '兩', '名',...
# tokens_v2       ['烏克蘭', '軍隊', '烏國', '俘虜', '俄羅斯', '軍隊', '中國', '...
# entities        [NerToken(word='烏克蘭軍隊', ner='ORG', idx=(0, 5))...
# token_pos       [('烏克蘭', 'Nc'), ('軍隊', 'Na'), ('在', 'P'), ('烏國...
# link             https://news.ltn.com.tw/news/world/paper/1701130
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 479, dtype: object
# Error at row 480: no such table: news_data2
# item_id                                          world_20250411_3
# date                                                   2025-04-11
# category                                                       國際
# title                                             法國最快6月承認「巴勒斯坦國」
# content         法國總統馬克宏透露，法國計劃在未來數月內承認巴勒斯坦國，並可能在六月於紐約的聯合國大會上正式...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('法國', 8), ('以色列', 7), ('巴勒斯坦', 7), ('巴勒斯坦國',...
# tokens          ['法國', '總統', '馬克宏', '透露', '，', '法國', '計劃', '在'...
# tokens_v2       ['法國', '總統', '馬克宏', '法國', '巴勒斯坦國', '紐約', '聯合國'...
# entities        [NerToken(word='法國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('法國', 'Nc'), ('總統', 'Na'), ('馬克宏', 'Nb'), ('...
# link             https://news.ltn.com.tw/news/world/paper/1701128
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 480, dtype: object
# Error at row 481: no such table: news_data2
# item_id                                          world_20250411_4
# date                                                   2025-04-11
# category                                                       國際
# title                                              拼接戰機 美「科學怪機」服役
# content         美國空軍近日宣布，由2架F-35戰機殘骸拼接而成的「科學怪機」已正式服役。這架重生戰機的零件...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('空軍', 6), ('戰機', 5), ('基地', 4), ('美國', 3), (...
# tokens          ['美國', '空軍', '近日', '宣布', '，', '由', '2', '架', '...
# tokens_v2       ['美國', '空軍', '戰機', '殘骸', '拼接', '科學怪機', '戰機', '...
# entities        [NerToken(word='近日', ner='DATE', idx=(4, 6)), ...
# token_pos       [('美國', 'Nc'), ('空軍', 'Nc'), ('近日', 'Nd'), ('宣...
# link             https://news.ltn.com.tw/news/world/paper/1701133
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 481, dtype: object
# Error at row 482: no such table: news_data2
# item_id                                          world_20250411_5
# date                                                   2025-04-11
# category                                                       國際
# title                                                川普重振造船業 反制中國
# content         美國總統川普九日簽署行政命令以振興美國造船業以及降低中國對全球航運的控制，並承諾在未來數年加...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('美國', 14), ('中國', 8), ('命令', 5), ('全球', 5), ...
# tokens          ['美國', '總統', '川普', '九日', '簽署', '行政', '命令', '以'...
# tokens_v2       ['美國', '總統', '川普', '簽署', '行政', '命令', '振興', '美國...
# entities        [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('美國', 'Nc'), ('總統', 'Na'), ('川普', 'Nb'), ('九...
# link             https://news.ltn.com.tw/news/world/paper/1701127
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 482, dtype: object
# Error at row 483: no such table: news_data2
# item_id                                          world_20250411_6
# date                                                   2025-04-11
# category                                                       國際
# title                                     關稅、台海兩大變數 AUKUS核潛艦交易蒙陰影
# content         路透獨家披露，「澳英美三方安全夥伴關係」（AUKUS）下的美國對澳核潛艦軍售計畫面臨新挑戰。...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('澳洲', 12), ('潛艦', 7), ('美國', 6), ('計畫', 5), ...
# tokens          ['路透', '獨家', '披露', '，', '「', '澳', '英', '美', '三...
# tokens_v2       ['夥伴', '關係', '美國', '核潛艦', '軍售', '計畫', '挑戰', '川...
# entities        [NerToken(word='澳', ner='GPE', idx=(8, 9)), Ne...
# token_pos       [('路透', 'VCL'), ('獨家', 'A'), ('披露', 'VE'), ('，...
# link             https://news.ltn.com.tw/news/world/paper/1701132
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 483, dtype: object
# Error at row 484: no such table: news_data2
# item_id                                          world_20250411_7
# date                                                   2025-04-11
# category                                                       國際
# title                                    中國在西半球軍事存在過大 美防長籲中美洲攜手抗中
# content         美國國防部長赫格塞斯繼宣稱中國是巴拿馬運河的威脅之後，九日再度強調，中國的軍事力量在西半球所...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('巴拿馬', 9), ('軍事', 6), ('中國', 5), ('基地', 4), ...
# tokens          ['美國', '國防部長', '赫格塞斯', '繼', '宣稱', '中國', '是', '...
# tokens_v2       ['美國', '國防部長', '赫格塞斯', '中國', '巴拿馬', '運河', '威脅'...
# entities        [NerToken(word='美國國防部長', ner='ORG', idx=(0, 6)...
# token_pos       [('美國', 'Nc'), ('國防部長', 'Na'), ('赫格塞斯', 'Nb'),...
# link             https://news.ltn.com.tw/news/world/paper/1701129
# photo_link      https://img.ltn.com.tw/Upload/news/250/2025/04...
# Name: 484, dtype: object
# Error at row 485: no such table: news_data2
# item_id                                          world_20250411_8
# date                                                   2025-04-11
# category                                                       國際
# title                                      一直升機墜入曼哈頓旁哈德遜河 消防單位搜救中
# content         美國當局表示，一架直升機今天墜入紐約曼哈頓（Manhattan）旁的哈德遜河（Hudson ...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('單位', 3), ('直升機', 2), ('救援', 2), ('美國', 1), ...
# tokens          ['美國', '當局', '表示', '，', '一', '架', '直升機', '今天',...
# tokens_v2       ['美國', '當局', '直升機', '紐約曼哈頓', '哈德遜河', '單位', '進行...
# entities        [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('美國', 'Nc'), ('當局', 'Na'), ('表示', 'VE'), ('，...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link                                                    NaN
# Name: 485, dtype: object
# Error at row 486: no such table: news_data2
# item_id                                          world_20250411_9
# date                                                   2025-04-11
# category                                                       國際
# title                                         白宮經濟顧問：已有15國就關稅協議提案
# content         美國總統川普突然暫緩實施部分對等關稅後，白宮經濟顧問哈塞特今天表示，美國正在認真考慮來自15...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('關稅', 10), ('美國', 5), ('中國', 5), ('白宮', 4), ...
# tokens          ['美國', '總統', '川普突然', '暫緩', '實施', '部分', '對等', '...
# tokens_v2       ['美國', '總統', '川普突然', '實施', '關稅', '白宮', '經濟', '...
# entities        [NerToken(word='美國', ner='GPE', idx=(0, 2)), N...
# token_pos       [('美國', 'Nc'), ('總統', 'Na'), ('川普突然', 'Nb'), (...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link                                                    NaN
# Name: 486, dtype: object
# Error at row 487: no such table: news_data2
# item_id                                         world_20250411_10
# date                                                   2025-04-11
# category                                                       國際
# title                                    華府機場又傳事故 美航飛機滑行道上被撞幸無人受傷
# content         美國聯邦航空總署（FAA）今天表示，一架載有幾名國會議員的美國航空公司（American A...
# sentiment                                                      暫無
# summary                                                        暫無
# top_key_freq    [('美國', 6), ('航空', 6), ('飛機', 4), ('機場', 4), (...
# tokens          ['美國', '聯邦', '航空', '總署', '（', 'FAA', '）', '今天'...
# tokens_v2       ['美國', '聯邦', '航空', '總署', '國會', '議員', '美國', '航空...
# entities        [NerToken(word='美國聯邦航空總署', ner='ORG', idx=(0, ...
# token_pos       [('美國', 'Nc'), ('聯邦', 'Na'), ('航空', 'Na'), ('總...
# link            https://news.ltn.com.tw/news/world/breakingnew...
# photo_link                                                    NaN
# Name: 487, dtype: object
